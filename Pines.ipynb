# %% [markdown]
# # Answer to Question 1 :
# Reading the csv file using pandas and storing it in a dataframe

# %%
import pandas as pd
data = pd.read_csv("Pines.csv", header=0, infer_datetime_format=True, parse_dates=[0], index_col=[0])

# %%
# Checking the shape of the data (dimensions)
data.shape

# 1000 rows and 15 columns
# Out:
# (1000, 15)

# %%
data.head()
# Out:
#    Row  Col  Hgt90  Hgt96  Diam96  Grow96  Hgt97  Diam97  Spread.97  \
# 1    1    1    NaN    NaN     NaN     NaN    NaN     NaN        NaN
# 2    1    2   14.0  284.0     4.2    96.0  362.0     6.6      162.0
# 3    1    3   17.0  387.0     7.4   110.0  442.0     9.3      250.0
# 4    1    4    NaN    NaN     NaN     NaN    NaN     NaN        NaN
# 5    1    5   24.0  294.0     3.9    70.0  369.0     7.0      176.0
#
#    Needles97  Deer95  Deer97  Cover95  Fert  Spacing
# 1        NaN     NaN     NaN        0     0       15
# 2       66.0     0.0     1.0        2     0       15
# 3       77.0     0.0     0.0        1     0       15
# 4        NaN     NaN     NaN        0     0       15
# 5       72.0     0.0     0.0        2     0       15

# %% [markdown]
# # Answer to Question 2 :

# %%
data.describe()
# Out:
#                Row          Col       Hgt90       Hgt96      Diam96  \
# count  1000.000000  1000.000000  818.000000  861.000000  851.000000
# mean     24.757000    12.412000   19.200611  279.272242    4.103055
# std      12.456368     7.450488    5.634271   72.888553    1.455728
# min       1.000000     1.000000    6.000000   11.000000    0.500000
# 25%      14.000000     6.000000   16.000000  235.000000    3.050000
# 50%      26.000000    12.000000   19.000000  289.000000    4.300000
# 75%      35.000000    18.000000   22.375000  329.000000    5.300000
# max      44.000000    30.000000   39.000000  491.000000    8.100000
#
#            Grow96       Hgt97      Diam97   Spread.97   Needles97      Deer95  \
# count  864.000000  865.000000  861.000000  864.000000  865.000000  871.000000
# mean    74.170370  346.618497    5.942009  182.565972   73.849249    0.239954
# std     21.212382   82.596395    1.892812   49.354727   13.064958    0.427301
# min      0.000000   87.000000    0.400000   20.000000   25.000000    0.000000
# 25%     64.000000  301.000000    4.700000  151.750000   65.000000    0.000000
# 50%     78.000000  357.000000    6.200000  185.000000   74.000000    0.000000
# 75%     90.000000  406.000000    7.400000  214.250000   82.000000    0.000000
# max    126.000000  558.000000   10.700000  339.000000  172.000000    1.000000
#
#            Deer97      Cover95         Fert      Spacing
# count  865.000000  1000.000000  1000.000000  1000.000000
# mean     0.106358     1.328000     0.507000    12.070000
# std      0.308474     1.141805     0.500201     2.463975
# min      0.000000     0.000000     0.000000    10.000000
# 25%      0.000000     0.000000     0.000000    10.000000
# 50%      0.000000     1.000000     1.000000    10.000000
# 75%      0.000000     2.000000     1.000000    15.000000
# max      1.000000     3.000000     1.000000    15.000000

# %%
# Observations :
# Max spacing is for 15 and Fertilizer for 1
# There are NA's visible in the numeric data

# %%
data.dtypes
# Here : all the variables are either integer or numeric
# Out:
# Row            int64
# Col            int64
# Hgt90        float64
# Hgt96        float64
# Diam96       float64
# Grow96       float64
# Hgt97        float64
# Diam97       float64
# Spread.97    float64
# Needles97    float64
# Deer95       float64
# Deer97       float64
# Cover95        int64
# Fert           int64
# Spacing        int64
# dtype: object

# %% [markdown]
# # Answer to Question 3 :

# %%
data['Hgt90'].fillna((data['Hgt90'].mean()), inplace=True)
data['Hgt96'].fillna((data['Hgt96'].mean()), inplace=True)
data['Diam96'].fillna((data['Diam96'].mean()), inplace=True)
data['Grow96'].fillna((data['Grow96'].mean()), inplace=True)
data['Hgt97'].fillna((data['Hgt97'].mean()), inplace=True)
data['Diam97'].fillna((data['Diam97'].mean()), inplace=True)
data['Spread.97'].fillna((data['Spread.97'].mean()), inplace=True)
data['Needles97'].fillna((data['Needles97'].mean()), inplace=True)

# %%
data.describe()
# Out:
#                Row          Col        Hgt90        Hgt96       Diam96  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean     24.757000    12.412000    19.200611   279.272242     4.103055
# std      12.456368     7.450488     5.095256    67.627885     1.342786
# min       1.000000     1.000000     6.000000    11.000000     0.500000
# 25%      14.000000     6.000000    16.750000   244.000000     3.300000
# 50%      26.000000    12.000000    19.200611   279.272242     4.103055
# 75%      35.000000    18.000000    21.925000   324.000000     5.100000
# max      44.000000    30.000000    39.000000   491.000000     8.100000
#
#             Grow96        Hgt97       Diam97    Spread.97    Needles97  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean     74.170370   346.618497     5.942009   182.565972    73.849249
# std      19.715696    76.813087     1.756199    45.872394    12.150164
# min       0.000000    87.000000     0.400000    20.000000    25.000000
# 25%      66.475000   310.000000     5.075000   158.000000    66.525000
# 50%      74.170370   346.618497     5.942009   182.565972    73.849249
# 75%      87.150000   399.000000     7.300000   209.000000    81.000000
# max     126.000000   558.000000    10.700000   339.000000   172.000000
#
#            Deer95      Deer97      Cover95         Fert      Spacing
# count  871.000000  865.000000  1000.000000  1000.000000  1000.000000
# mean     0.239954    0.106358     1.328000     0.507000    12.070000
# std      0.427301    0.308474     1.141805     0.500201     2.463975
# min      0.000000    0.000000     0.000000     0.000000    10.000000
# 25%      0.000000    0.000000     0.000000     0.000000    10.000000
# 50%      0.000000    0.000000     1.000000     1.000000    10.000000
# 75%      0.000000    0.000000     2.000000     1.000000    15.000000
# max      1.000000    1.000000     3.000000     1.000000    15.000000

# %% [markdown]
# # Answer to Question : 4

# %%
df=data[data.columns[2:10]]
df.corr()
# Out:
#               Hgt90     Hgt96    Diam96    Grow96     Hgt97    Diam97  \
# Hgt90      1.000000  0.167396  0.156319  0.071612  0.152295  0.194100
# Hgt96      0.167396  1.000000  0.834928  0.758209  0.944023  0.849267
# Diam96     0.156319  0.834928  1.000000  0.524696  0.797172  0.869299
# Grow96     0.071612  0.758209  0.524696  1.000000  0.740293  0.591163
# Hgt97      0.152295  0.944023  0.797172  0.740293  1.000000  0.845702
# Diam97     0.194100  0.849267  0.869299  0.591163  0.845702  1.000000
# Spread.97  0.167444  0.751193  0.716463  0.559283  0.756597  0.767795
# Needles97  0.126726  0.113681  0.113357  0.052041  0.115345  0.151748
#
#            Spread.97  Needles97
# Hgt90       0.167444   0.126726
# Hgt96       0.751193   0.113681
# Diam96      0.716463   0.113357
# Grow96      0.559283   0.052041
# Hgt97       0.756597   0.115345
# Diam97      0.767795   0.151748
# Spread.97   1.000000   0.197803
# Needles97   0.197803   1.000000

# %% [markdown]
# # Answer to Question 5 :

# %%
# As observed from the previous output : Hgt96 is the most correlated variable with Hgt97 : 94%

# %% [markdown]
# # Answer to Question 6:
# Create a two-way frequency table for fert vs spacing variables ?

# %%
fert_spacing= pd.crosstab(index=data["Spacing"], 
                           columns=data["Fert"])

fert_spacing.index= ["10","15"]

fert_spacing
# Out:
# Fert    0    1
# 10    285  301
# 15    208  206

# %%
# 15 spacing has the most number of rows out of the total observations

# %% [markdown]
# # Answer to Question 7:

# %%
fert_spacing= pd.crosstab(index=data["Fert"], 
                           columns=data["Spacing"])

fert_spacing.index= ["Fertilizer : Yes", "Fertilizer : No"]

fert_spacing
# Out:
# Spacing            10   15
# Fertilizer : Yes  285  208
# Fertilizer : No   301  206

# %%
# Fertilizer Intake (1) has the most number of rows out of the total observations
# With respect to fertilizer intake (1) , 10 spacing has the most no. of observations

# %% [markdown]
# # Answer to Question 8 :
#
# Plotting a histogram for the variable 'Cover95'

# %%
my_tab = pd.crosstab(index = data["Cover95"],  # Make a crosstab
                              columns="count")      # Name the count column

my_tab.plot.bar()

# Thorny cover in September 1995 (None  has the most number of observations in the given dataset)

# %%
my_tab = pd.crosstab(index=data["Cover95"],  # Make a crosstab
                              columns="count")      # Name the count column

my_tab
# Out:
# col_0    count
# Cover95
# 0          326
# 1          235
# 2          224
# 3          215

# %% [markdown]
# # Answer to Question 9 :

# %%
import numpy as np
import matplotlib.pyplot as plt
from pandas.plotting import scatter_matrix

plot_df=data[data.columns[2:4]]
scatter_matrix(plot_df,figsize=(2,2), diagonal='kde')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001E22A8538C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E22A87F888>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001E22A8B97C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E22A8F28C8>]],
#       dtype=object)

# %% [markdown]
# # Answer to Question 10 :

# %%
import statsmodels.api as sm
from statsmodels.formula.api import ols
model1 = ols("Hgt96 ~ Hgt90", data=data).fit()

# summarize our model
model1_summary = model1.summary()

# %%
from IPython.display import HTML, display
HTML(
(model1_summary
    .as_html()
    .replace('<th>  Adj. R-squared:    </th>', '<th style="background-color:#aec7e8;"> Adj. R-squared: </th>')
    .replace('<th>coef</th>', '<th style="background-color:#ffbb78;">coef</th>')
    .replace('<th>std err</th>', '<th style="background-color:#c7e9c0;">std err</th>')
    .replace('<th>P>|t|</th>', '<th style="background-color:#bcbddc;">P>|t|</th>')
    .replace('<th>[0.025</th>    <th>0.975]</th>', '<th style="background-color:#ff9896;">[0.025</th>    <th style="background-color:#ff9896;">0.975]</th>'))
)
# Out:
# <table class="simpletable">
# <caption>OLS Regression Results</caption>
# <tr>
#   <th>Dep. Variable:</th>          <td>Hgt96</td>      <th>  R-squared:         </th> <td>   0.028</td>
# </tr>
# <tr>
#   <th>Model:</th>                   <td>OLS</td>       <th style="background-color:#aec7e8;"> Adj. R-squared: </th> <td>   0.027</td>
# </tr>
# <tr>
#   <th>Method:</th>             <td>Least Squares</td>  <th>  F-statistic:       </th> <td>   28.77</td>
# </tr>
# <tr>
#   <th>Date:</th>             <td>Tue, 24 Mar 2020</td> <th>  Prob (F-statistic):</th> <td>1.01e-07</td>
# </tr>
# <tr>
#   <th>Time:</th>                 <td>02:15:46</td>     <th>  Log-Likelihood:    </th> <td> -5618.2</td>
# </tr>
# <tr>
#   <th>No. Observations:</th>      <td>  1000</td>      <th>  AIC:               </th> <td>1.124e+04</td>
# </tr>
# <tr>
#   <th>Df Residuals:</th>          <td>   998</td>      <th>  BIC:               </th> <td>1.125e+04</td>
# </tr>
# <tr>
#   <th>Df Model:</th>              <td>     1</td>      <th>                     </th>     <td> </td>
# </tr>
# <tr>
#   <th>Covariance Type:</th>      <td>nonrobust</td>    <th>                     </th>     <td> </td>
# </tr>
# </table>
# <table class="simpletable">
# <tr>
#       <td></td>         <th style="background-color:#ffbb78;">coef</th>     <th style="background-color:#c7e9c0;">std err</th>      <th>t</th>      <th style="background-color:#bcbddc;">P>|t|</th>  <th style="background-color:#ff9896;">[0.025</th>    <th style="background-color:#ff9896;">0.975]</th>
# </tr>
# <tr>
#   <th>Intercept</th> <td>  236.6124</td> <td>    8.228</td> <td>   28.757</td> <td> 0.000</td> <td>  220.466</td> <td>  252.759</td>
# </tr>
# <tr>
#   <th>Hgt90</th>     <td>    2.2218</td> <td>    0.414</td> <td>    5.364</td> <td> 0.000</td> <td>    1.409</td> <td>    3.035</td>
# </tr>
# </table>
# <table class="simpletable">
# <tr>
#   <th>Omnibus:</th>       <td>46.236</td> <th>  Durbin-Watson:     </th> <td>   1.642</td>
# </tr>
# <tr>
#   <th>Prob(Omnibus):</th> <td> 0.000</td> <th>  Jarque-Bera (JB):  </th> <td>  54.128</td>
# </tr>
# <tr>
#   <th>Skew:</th>          <td>-0.492</td> <th>  Prob(JB):          </th> <td>1.76e-12</td>
# </tr>
# <tr>
#   <th>Kurtosis:</th>      <td> 3.577</td> <th>  Cond. No.          </th> <td>    77.7</td>
# </tr>
# </table><br/><br/>Warnings:<br/>[1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# The line means that hat(height in 1996 in cm)=236.612 + 2.22(height in 1990 in cm). 
# That means that for each increase in cm in 1990 the tree in 1996 will be 2.22 cm higher in the prediction.
#Looking at the summary of the simple linear model, I am not satisfied with it. 
#The Multiple R-squared & the Adjusted R Squared value is ~0.03 
# This means that the height in 1990 in cm only counts for ~3% of the tree’s height in 1996 in cm variation that is explained by the linear regression model. 
#This is not enough for me to feel satisfied with the linear model.

# %% [markdown]
# # Answer to Question : 11

# %%
# This produces our four regression plots for Hgt96

fig = plt.figure(figsize=(15,8))

# pass in the model as the first parameter, then specify the 
# predictor variable we want to analyze
fig = sm.graphics.plot_regress_exog(model1, "Hgt90", fig=fig)

# %% [markdown]
# # Answer to Question 12 :

# %%
model2 = ols("Hgt97 ~ Hgt90+Fert", data=data).fit()

# summarize our model
model2_summary = model2.summary()

HTML(model2_summary.as_html())
# Out:
# <table class="simpletable">
# <caption>OLS Regression Results</caption>
# <tr>
#   <th>Dep. Variable:</th>          <td>Hgt97</td>      <th>  R-squared:         </th> <td>   0.076</td>
# </tr>
# <tr>
#   <th>Model:</th>                   <td>OLS</td>       <th>  Adj. R-squared:    </th> <td>   0.074</td>
# </tr>
# <tr>
#   <th>Method:</th>             <td>Least Squares</td>  <th>  F-statistic:       </th> <td>   40.78</td>
# </tr>
# <tr>
#   <th>Date:</th>             <td>Tue, 24 Mar 2020</td> <th>  Prob (F-statistic):</th> <td>9.48e-18</td>
# </tr>
# <tr>
#   <th>Time:</th>                 <td>02:15:48</td>     <th>  Log-Likelihood:    </th> <td> -5720.5</td>
# </tr>
# <tr>
#   <th>No. Observations:</th>      <td>  1000</td>      <th>  AIC:               </th> <td>1.145e+04</td>
# </tr>
# <tr>
#   <th>Df Residuals:</th>          <td>   997</td>      <th>  BIC:               </th> <td>1.146e+04</td>
# </tr>
# <tr>
#   <th>Df Model:</th>              <td>     2</td>      <th>                     </th>     <td> </td>
# </tr>
# <tr>
#   <th>Covariance Type:</th>      <td>nonrobust</td>    <th>                     </th>     <td> </td>
# </tr>
# </table>
# <table class="simpletable">
# <tr>
#       <td></td>         <th>coef</th>     <th>std err</th>      <th>t</th>      <th>P>|t|</th>  <th>[0.025</th>    <th>0.975]</th>
# </tr>
# <tr>
#   <th>Intercept</th> <td>  316.7611</td> <td>    9.313</td> <td>   34.014</td> <td> 0.000</td> <td>  298.486</td> <td>  335.036</td>
# </tr>
# <tr>
#   <th>Hgt90</th>     <td>    2.4849</td> <td>    0.460</td> <td>    5.405</td> <td> 0.000</td> <td>    1.583</td> <td>    3.387</td>
# </tr>
# <tr>
#   <th>Fert</th>      <td>  -35.2138</td> <td>    4.683</td> <td>   -7.520</td> <td> 0.000</td> <td>  -44.403</td> <td>  -26.024</td>
# </tr>
# </table>
# <table class="simpletable">
# <tr>
#   <th>Omnibus:</th>       <td>72.168</td> <th>  Durbin-Watson:     </th> <td>   1.732</td>
# </tr>
# <tr>
#   <th>Prob(Omnibus):</th> <td> 0.000</td> <th>  Jarque-Bera (JB):  </th> <td>  97.078</td>
# </tr>
# <tr>
#   <th>Skew:</th>          <td>-0.604</td> <th>  Prob(JB):          </th> <td>8.31e-22</td>
# </tr>
# <tr>
#   <th>Kurtosis:</th>      <td> 3.933</td> <th>  Cond. No.          </th> <td>    79.9</td>
# </tr>
# </table><br/><br/>Warnings:<br/>[1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# The line means that hat(height in 1997 in cm)=316.761 + 2.485(height in 1990 in cm) - 35.214(fertilizer use)
# That means that for each increase in cm in 1990 the tree in 1997 will be 2.485 cm higher in the prediction and 
# For each increase in fertilizer intake ; the tree in 1997 will be 35.214 cm lower in prediction

# %% [markdown]
# # Answer to Question 13 :

# %%
#Looking at the summary of the simple linear model, I am not satisfied with it. 
#The Multiple R-squared & the Adjusted R Squared value is ~0.07
# This means that the height in 1990 in cm only counts for ~7% of the tree’s height in 1997 in cm variation that is explained by the linear regression model. 
#This is not enough for me to feel satisfied with the linear model.

# %% [markdown]
# # Answer to Question 14 :

# %%
# This produces our four regression plots for predictors : Hgt90

fig = plt.figure(figsize=(15,8))

# pass in the model as the first parameter, then specify the 
# predictor variable we want to analyze
fig = sm.graphics.plot_regress_exog(model2, "Hgt90", fig=fig)

# %%
# this produces our six partial regression plots
fig = plt.figure(figsize=(20,12))
fig = sm.graphics.plot_partregress_grid(model2, fig=fig)

# %% [markdown]
# # Answer to Question 15 :

# %%
model3 = ols("Hgt97 ~ Hgt90+Fert+Hgt96", data=data).fit()

# summarize our model
model3_summary = model3.summary()

HTML(model3_summary.as_html())
# Out:
# <table class="simpletable">
# <caption>OLS Regression Results</caption>
# <tr>
#   <th>Dep. Variable:</th>          <td>Hgt97</td>      <th>  R-squared:         </th> <td>   0.891</td>
# </tr>
# <tr>
#   <th>Model:</th>                   <td>OLS</td>       <th>  Adj. R-squared:    </th> <td>   0.891</td>
# </tr>
# <tr>
#   <th>Method:</th>             <td>Least Squares</td>  <th>  F-statistic:       </th> <td>   2723.</td>
# </tr>
# <tr>
#   <th>Date:</th>             <td>Tue, 24 Mar 2020</td> <th>  Prob (F-statistic):</th>  <td>  0.00</td>
# </tr>
# <tr>
#   <th>Time:</th>                 <td>02:15:51</td>     <th>  Log-Likelihood:    </th> <td> -4650.1</td>
# </tr>
# <tr>
#   <th>No. Observations:</th>      <td>  1000</td>      <th>  AIC:               </th> <td>   9308.</td>
# </tr>
# <tr>
#   <th>Df Residuals:</th>          <td>   996</td>      <th>  BIC:               </th> <td>   9328.</td>
# </tr>
# <tr>
#   <th>Df Model:</th>              <td>     3</td>      <th>                     </th>     <td> </td>
# </tr>
# <tr>
#   <th>Covariance Type:</th>      <td>nonrobust</td>    <th>                     </th>     <td> </td>
# </tr>
# </table>
# <table class="simpletable">
# <tr>
#       <td></td>         <th>coef</th>     <th>std err</th>      <th>t</th>      <th>P>|t|</th>  <th>[0.025</th>    <th>0.975]</th>
# </tr>
# <tr>
#   <th>Intercept</th> <td>   49.9166</td> <td>    4.442</td> <td>   11.237</td> <td> 0.000</td> <td>   41.200</td> <td>   58.633</td>
# </tr>
# <tr>
#   <th>Hgt90</th>     <td>   -0.0736</td> <td>    0.160</td> <td>   -0.459</td> <td> 0.647</td> <td>   -0.388</td> <td>    0.241</td>
# </tr>
# <tr>
#   <th>Fert</th>      <td>   -1.6475</td> <td>    1.653</td> <td>   -0.997</td> <td> 0.319</td> <td>   -4.891</td> <td>    1.596</td>
# </tr>
# <tr>
#   <th>Hgt96</th>     <td>    1.0705</td> <td>    0.012</td> <td>   86.462</td> <td> 0.000</td> <td>    1.046</td> <td>    1.095</td>
# </tr>
# </table>
# <table class="simpletable">
# <tr>
#   <th>Omnibus:</th>       <td>548.701</td> <th>  Durbin-Watson:     </th> <td>   1.885</td>
# </tr>
# <tr>
#   <th>Prob(Omnibus):</th> <td> 0.000</td>  <th>  Jarque-Bera (JB):  </th> <td>33557.555</td>
# </tr>
# <tr>
#   <th>Skew:</th>          <td>-1.713</td>  <th>  Prob(JB):          </th> <td>    0.00</td>
# </tr>
# <tr>
#   <th>Kurtosis:</th>      <td>31.172</td>  <th>  Cond. No.          </th> <td>1.61e+03</td>
# </tr>
# </table><br/><br/>Warnings:<br/>[1] Standard Errors assume that the covariance matrix of the errors is correctly specified.<br/>[2] The condition number is large, 1.61e+03. This might indicate that there are<br/>strong multicollinearity or other numerical problems.

# %%
# The line means that hat(height in 1997 in cm)=49.9166 + 1.0705(height in 1996) -0.0736 (height in 1990 in cm) - 1.6475 (fertilizer use)
# That means that for each increase in cm in 1996 the tree in 1997 will be ~1 cm higher in the prediction 
# For each increase in cm in 1990 the tree in 1997 will be 0.07 cm lower in the prediction 
# For each increase in fertilizer intake ; the tree in 1997 will be 1.65 cm lower in the prediction

# %% [markdown]
# # Answer in Question 16 :

# %%
# Yes, this model does a much better job of predicting tree height in 1997

#Looking at the summary of the simple linear model, I am pretty satisfied with it. 
#The Multiple R-squared & the Adjusted R Squared value is 0.891
#This means that the model counts for 89% of the tree’s height in 1997 in cm variation that is explained by the linear regression model.

# %% [markdown]
# # Answer in Question 17 :

# %%
# This produces our four regression plots for predictors : Hgt96

fig = plt.figure(figsize=(15,8))

# pass in the model as the first parameter, then specify the 
# predictor variable we want to analyze
fig = sm.graphics.plot_regress_exog(model3, "Hgt96", fig=fig)

# %%
# this produces our six partial regression plots
fig = plt.figure(figsize=(20,12))
fig = sm.graphics.plot_partregress_grid(model3, fig=fig)

# %% [markdown]
# # Answer in Question 18 :

# %%
model4 = ols("Hgt97 ~ Diam97+Fert+Hgt96", data=data).fit()

# summarize our model
model4_summary = model4.summary()

HTML(model4_summary.as_html())
# Out:
# <table class="simpletable">
# <caption>OLS Regression Results</caption>
# <tr>
#   <th>Dep. Variable:</th>          <td>Hgt97</td>      <th>  R-squared:         </th> <td>   0.898</td>
# </tr>
# <tr>
#   <th>Model:</th>                   <td>OLS</td>       <th>  Adj. R-squared:    </th> <td>   0.898</td>
# </tr>
# <tr>
#   <th>Method:</th>             <td>Least Squares</td>  <th>  F-statistic:       </th> <td>   2930.</td>
# </tr>
# <tr>
#   <th>Date:</th>             <td>Tue, 24 Mar 2020</td> <th>  Prob (F-statistic):</th>  <td>  0.00</td>
# </tr>
# <tr>
#   <th>Time:</th>                 <td>02:15:54</td>     <th>  Log-Likelihood:    </th> <td> -4617.4</td>
# </tr>
# <tr>
#   <th>No. Observations:</th>      <td>  1000</td>      <th>  AIC:               </th> <td>   9243.</td>
# </tr>
# <tr>
#   <th>Df Residuals:</th>          <td>   996</td>      <th>  BIC:               </th> <td>   9262.</td>
# </tr>
# <tr>
#   <th>Df Model:</th>              <td>     3</td>      <th>                     </th>     <td> </td>
# </tr>
# <tr>
#   <th>Covariance Type:</th>      <td>nonrobust</td>    <th>                     </th>     <td> </td>
# </tr>
# </table>
# <table class="simpletable">
# <tr>
#       <td></td>         <th>coef</th>     <th>std err</th>      <th>t</th>      <th>P>|t|</th>  <th>[0.025</th>    <th>0.975]</th>
# </tr>
# <tr>
#   <th>Intercept</th> <td>   50.1179</td> <td>    3.643</td> <td>   13.756</td> <td> 0.000</td> <td>   42.968</td> <td>   57.268</td>
# </tr>
# <tr>
#   <th>Diam97</th>    <td>    6.8870</td> <td>    0.838</td> <td>    8.222</td> <td> 0.000</td> <td>    5.243</td> <td>    8.531</td>
# </tr>
# <tr>
#   <th>Fert</th>      <td>   -1.5023</td> <td>    1.592</td> <td>   -0.943</td> <td> 0.346</td> <td>   -4.627</td> <td>    1.623</td>
# </tr>
# <tr>
#   <th>Hgt96</th>     <td>    0.9179</td> <td>    0.022</td> <td>   41.968</td> <td> 0.000</td> <td>    0.875</td> <td>    0.961</td>
# </tr>
# </table>
# <table class="simpletable">
# <tr>
#   <th>Omnibus:</th>       <td>509.140</td> <th>  Durbin-Watson:     </th> <td>   1.909</td>
# </tr>
# <tr>
#   <th>Prob(Omnibus):</th> <td> 0.000</td>  <th>  Jarque-Bera (JB):  </th> <td>21145.034</td>
# </tr>
# <tr>
#   <th>Skew:</th>          <td>-1.631</td>  <th>  Prob(JB):          </th> <td>    0.00</td>
# </tr>
# <tr>
#   <th>Kurtosis:</th>      <td>25.290</td>  <th>  Cond. No.          </th> <td>1.38e+03</td>
# </tr>
# </table><br/><br/>Warnings:<br/>[1] Standard Errors assume that the covariance matrix of the errors is correctly specified.<br/>[2] The condition number is large, 1.38e+03. This might indicate that there are<br/>strong multicollinearity or other numerical problems.

# %%
# The line means that hat(height in 1997 in cm)=50.1179 + 0.9179(height in 1996) +6.8870 (tree trunk diameter in 1997 in cm) - 1.5023 (fertilizer use)
# That means that for each increase in cm in 1996 the tree in 1997 will be ~1 cm higher in the prediction 
# For each increase in diameter cm in 1997 the tree in 1997 will be ~7 cm higher in the prediction 
# For each increase in fertilizer intake ; the tree in 1997 will be 1.5 cm lower in the prediction

# %% [markdown]
# # Solution to Question 19 :

# %%
# Yes, this model does a much better job of predicting tree height in 1997

#Looking at the summary of the simple linear model, I am pretty satisfied with it. 
#The Multiple R-squared & the Adjusted R Squared value is 0.8979
#This means that the model counts for ~90% of the tree’s height in 1997 in cm variation that is explained by the linear regression model.

# %% [markdown]
# # Solution to Question 20 :

# %%
# Model 4 is the best fit out of the all 4 models with the highest R-Square value of 90%

# Model4 (R^2 of 0.8982) > Model 3 (R^2 of 0.8913) > Model 2 ( R^2 of 0.075) > Model 1 (R^2 of 0.028)
